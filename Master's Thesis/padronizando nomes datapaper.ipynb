# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
cameta = gpd.read_file("C:\\Bruno\\packages\\amazonULC\\data-raw\\raw-images\\nivel1_cameta.shp")

# %%
sorted(list(cameta.columns))
# Out:
# ['ASM_max',
#  'ASM_mean',
#  'ASM_min',
#  'ASM_stddev',
#  'ASM_sum',
#  'B0_Amplitu',
#  'B0_Contras',
#  'B0_Dissimi',
#  'B0_Energy',
#  'B0_Entropy',
#  'B0_Homogen',
#  'B0_Kurtosi',
#  'B0_Max_Val',
#  'B0_Mean',
#  'B0_Median',
#  'B0_Min_Val',
#  'B0_Skewnes',
#  'B0_Standar',
#  'B0_Sum',
#  'B0_Var_Coe',
#  'B1_Amplitu',
#  'B1_Contras',
#  'B1_Dissimi',
#  'B1_Energy',
#  'B1_Entropy',
#  'B1_Homogen',
#  'B1_Kurtosi',
#  'B1_Max_Val',
#  'B1_Mean',
#  'B1_Median',
#  'B1_Min_Val',
#  'B1_Skewnes',
#  'B1_Standar',
#  'B1_Sum',
#  'B1_Var_Coe',
#  'B2_Amplitu',
#  'B2_Contras',
#  'B2_Dissimi',
#  'B2_Energy',
#  'B2_Entropy',
#  'B2_Homogen',
#  'B2_Kurtosi',
#  'B2_Max_Val',
#  'B2_Mean',
#  'B2_Median',
#  'B2_Min_Val',
#  'B2_Skewnes',
#  'B2_Standar',
#  'B2_Sum',
#  'B2_Var_Coe',
#  'B3_Amplitu',
#  'B3_Contras',
#  'B3_Dissimi',
#  'B3_Energy',
#  'B3_Entropy',
#  'B3_Homogen',
#  'B3_Kurtosi',
#  'B3_Max_Val',
#  'B3_Mean',
#  'B3_Median',
#  'B3_Min_Val',
# ...

# %%
maraba = gpd.read_file("C:\\Bruno\\packages\\amazonULC\\data-raw\\raw-images\\nivel1_maraba.shp")

# %%
sorted(list(maraba.columns))
# Out:
# ['ASM_MAX',
#  'ASM_MEAN',
#  'ASM_MIN',
#  'ASM_STDDEV',
#  'ASM_SUM',
#  'B0_Amplitu',
#  'B0_Contras',
#  'B0_Dissimi',
#  'B0_Energy',
#  'B0_Entropy',
#  'B0_Homogen',
#  'B0_Kurtosi',
#  'B0_Max_Val',
#  'B0_Mean',
#  'B0_Median',
#  'B0_Min_Val',
#  'B0_Skewnes',
#  'B0_Standar',
#  'B0_Sum',
#  'B0_Var_Coe',
#  'B1_Amplitu',
#  'B1_Contras',
#  'B1_Dissimi',
#  'B1_Energy',
#  'B1_Entropy',
#  'B1_Homogen',
#  'B1_Kurtosi',
#  'B1_Max_Val',
#  'B1_Mean',
#  'B1_Median',
#  'B1_Min_Val',
#  'B1_Skewnes',
#  'B1_Standar',
#  'B1_Sum',
#  'B1_Var_Coe',
#  'B2_Amplitu',
#  'B2_Contras',
#  'B2_Dissimi',
#  'B2_Energy',
#  'B2_Entropy',
#  'B2_Homogen',
#  'B2_Kurtosi',
#  'B2_Max_Val',
#  'B2_Mean',
#  'B2_Median',
#  'B2_Min_Val',
#  'B2_Skewnes',
#  'B2_Standar',
#  'B2_Sum',
#  'B2_Var_Coe',
#  'B3_Amplitu',
#  'B3_Contras',
#  'B3_Dissimi',
#  'B3_Energy',
#  'B3_Entropy',
#  'B3_Homogen',
#  'B3_Kurtosi',
#  'B3_Max_Val',
#  'B3_Mean',
#  'B3_Median',
#  'B3_Min_Val',
# ...

# %%
altamira = gpd.read_file("C:\\Bruno\\packages\\amazonULC\\data-raw\\raw-images\\nivel1_altamira.shp")

# %%
sorted(list(altamira.columns))
# Out:
# ['ASM [MAX]',
#  'ASM [MEAN]',
#  'ASM [MIN]',
#  'ASM [STDDE',
#  'ASM [SUM]',
#  'B0_Amplitu',
#  'B0_Contras',
#  'B0_Dissimi',
#  'B0_Energy',
#  'B0_Entropy',
#  'B0_Homogen',
#  'B0_Kurtosi',
#  'B0_Max_Val',
#  'B0_Mean',
#  'B0_Median',
#  'B0_Min_Val',
#  'B0_Skewnes',
#  'B0_Standar',
#  'B0_Sum',
#  'B0_Var_Coe',
#  'B1_Amplitu',
#  'B1_Contras',
#  'B1_Dissimi',
#  'B1_Energy',
#  'B1_Entropy',
#  'B1_Homogen',
#  'B1_Kurtosi',
#  'B1_Max_Val',
#  'B1_Mean',
#  'B1_Median',
#  'B1_Min_Val',
#  'B1_Skewnes',
#  'B1_Standar',
#  'B1_Sum',
#  'B1_Var_Coe',
#  'B2_Amplitu',
#  'B2_Contras',
#  'B2_Dissimi',
#  'B2_Energy',
#  'B2_Entropy',
#  'B2_Homogen',
#  'B2_Kurtosi',
#  'B2_Max_Val',
#  'B2_Mean',
#  'B2_Median',
#  'B2_Min_Val',
#  'B2_Skewnes',
#  'B2_Standar',
#  'B2_Sum',
#  'B2_Var_Coe',
#  'B3_Amplitu',
#  'B3_Contras',
#  'B3_Dissimi',
#  'B3_Energy',
#  'B3_Entropy',
#  'B3_Homogen',
#  'B3_Kurtosi',
#  'B3_Max_Val',
#  'B3_Mean',
#  'B3_Median',
# ...

# %%
altamira_target = gpd.read_file("C:\\Users\\brdia\\Downloads\\dados\\altamira_target.shp")

# %%
altamira_merge = altamira.merge(altamira_target[['DN','_class']], left_on = 'DN', right_on = 'DN' )

# %%
altamira_merge
# Out:
#             DN  MOC1 [MIN]  MOC1 [MAX]  MOC1 [SUM]  MOC1 [MEAN  MOC1 [STDD  \
# 0            1         NaN         NaN         NaN         NaN         NaN
# 1            2         NaN         NaN         NaN         NaN         NaN
# 2            3         NaN         NaN         NaN         NaN         NaN
# 3            4         NaN         NaN         NaN         NaN         NaN
# 4            6         NaN         NaN         NaN         NaN         NaN
# ...        ...         ...         ...         ...         ...         ...
# 228786  176701   -0.191555   -0.175796  -13.849587   -0.184661    0.003837
# 228787  176709   -0.192644   -0.174526  -15.402990   -0.183369    0.004471
# 228788  176716   -0.194449   -0.178775   -8.937455   -0.186197    0.004209
# 228789  176708   -0.193978   -0.183757  -11.525691   -0.188946    0.002885
# 228790  176707   -0.182776   -0.173883   -7.841303   -0.178211    0.002239
#
# ...

# %%
sorted(altamira_merge)
# Out:
# ['ASM [MAX]',
#  'ASM [MEAN]',
#  'ASM [MIN]',
#  'ASM [STDDE',
#  'ASM [SUM]',
#  'B0_Amplitu',
#  'B0_Contras',
#  'B0_Dissimi',
#  'B0_Energy',
#  'B0_Entropy',
#  'B0_Homogen',
#  'B0_Kurtosi',
#  'B0_Max_Val',
#  'B0_Mean',
#  'B0_Median',
#  'B0_Min_Val',
#  'B0_Skewnes',
#  'B0_Standar',
#  'B0_Sum',
#  'B0_Var_Coe',
#  'B1_Amplitu',
#  'B1_Contras',
#  'B1_Dissimi',
#  'B1_Energy',
#  'B1_Entropy',
#  'B1_Homogen',
#  'B1_Kurtosi',
#  'B1_Max_Val',
#  'B1_Mean',
#  'B1_Median',
#  'B1_Min_Val',
#  'B1_Skewnes',
#  'B1_Standar',
#  'B1_Sum',
#  'B1_Var_Coe',
#  'B2_Amplitu',
#  'B2_Contras',
#  'B2_Dissimi',
#  'B2_Energy',
#  'B2_Entropy',
#  'B2_Homogen',
#  'B2_Kurtosi',
#  'B2_Max_Val',
#  'B2_Mean',
#  'B2_Median',
#  'B2_Min_Val',
#  'B2_Skewnes',
#  'B2_Standar',
#  'B2_Sum',
#  'B2_Var_Coe',
#  'B3_Amplitu',
#  'B3_Contras',
#  'B3_Dissimi',
#  'B3_Energy',
#  'B3_Entropy',
#  'B3_Homogen',
#  'B3_Kurtosi',
#  'B3_Max_Val',
#  'B3_Mean',
#  'B3_Median',
# ...

# %%
altamira_merge = altamira_merge[['DN',
'ASM [MAX]',
 'ASM [MEAN]',
 'ASM [MIN]',
 'ASM [STDDE',
 'ASM [SUM]',
 'B0_Amplitu',
 'B0_Contras',
 'B0_Dissimi',
 'B0_Energy',
 'B0_Entropy',
 'B0_Homogen',
 'B0_Kurtosi',
 'B0_Max_Val',
 'B0_Mean',
 'B0_Median',
 'B0_Min_Val',
 'B0_Skewnes',
 'B0_Standar',
 'B0_Sum',
 'B0_Var_Coe',
 'B1_Amplitu',
 'B1_Contras',
 'B1_Dissimi',
 'B1_Energy',
 'B1_Entropy',
 'B1_Homogen',
 'B1_Kurtosi',
 'B1_Max_Val',
 'B1_Mean',
 'B1_Median',
 'B1_Min_Val',
 'B1_Skewnes',
 'B1_Standar',
 'B1_Sum',
 'B1_Var_Coe',
 'B2_Amplitu',
 'B2_Contras',
 'B2_Dissimi',
 'B2_Energy',
 'B2_Entropy',
 'B2_Homogen',
 'B2_Kurtosi',
 'B2_Max_Val',
 'B2_Mean',
 'B2_Median',
 'B2_Min_Val',
 'B2_Skewnes',
 'B2_Standar',
 'B2_Sum',
 'B2_Var_Coe',
 'B3_Amplitu',
 'B3_Contras',
 'B3_Dissimi',
 'B3_Energy',
 'B3_Entropy',
 'B3_Homogen',
 'B3_Kurtosi',
 'B3_Max_Val',
 'B3_Mean',
 'B3_Median',
 'B3_Min_Val',
 'B3_Skewnes',
 'B3_Standar',
 'B3_Sum',
 'B3_Var_Coe',
 'BAI [MAX]',
 'BAI [MEAN]',
 'BAI [MIN]',
 'BAI [STDDEV',
 'BAI [SUM]',
 'BAINIR [MAX',
 'BAINIR [MEA',
 'BAINIR [MIN',
 'BAINIR [STD',
 'BAINIR [SUM',
 'CONT [MAX]',
 'CONT [MEAN',
 'CONT [MIN]',
 'CONT [STDD',
 'CONT [SUM]',
 'CORR [MAX]',
 'CORR [MEAN',
 'CORR [MIN]',
 'CORR [STDD',
 'CORR [SUM]',
 'ENTR [MAX]',
 'ENTR [MEAN',
 'ENTR [MIN]',
 'ENTR [STDD',
 'ENTR [SUM]',
 'MOC1 [MAX]',
 'MOC1 [MEAN',
 'MOC1 [MIN]',
 'MOC1 [STDD',
 'MOC1 [SUM]',
 'NDVI [MAX]',
 'NDVI [MEAN]',
 'NDVI [MIN]',
 'NDVI [STDDE',
 'NDVI [SUM]',
 'PBOX_AREA',
 'PBOX_LEN',
 'PBOX_PERIM',
 'PBOX_WIDTH',
 'PCIRCLE',
 'PDENSITY',
 'PELLIP_FIT',
 'PGYRATIUS',
 'POLRADIUS',
 'POL_ANGLE',
 'PRECTFIT',
 'PSAHPEIDX',
 'P_AREA',
 'P_COMPAC',
 'P_FRACDIM',
 'P_PERARAT',
 'P_PERIM',
 '_class',
 'geometry']]

# %%
altamira_merge.columns = [ 'ID',
 'ASM_max',
 'ASM_mean',
 'ASM_min',
 'ASM_stddev',
 'ASM_sum',
 'B0_Amplitu',
 'B0_Contras',
 'B0_Dissimi',
 'B0_Energy',
 'B0_Entropy',
 'B0_Homogen',
 'B0_Kurtosi',
 'B0_Max_Val',
 'B0_Mean',
 'B0_Median',
 'B0_Min_Val',
 'B0_Skewnes',
 'B0_Standar',
 'B0_Sum',
 'B0_Var_Coe',
 'B1_Amplitu',
 'B1_Contras',
 'B1_Dissimi',
 'B1_Energy',
 'B1_Entropy',
 'B1_Homogen',
 'B1_Kurtosi',
 'B1_Max_Val',
 'B1_Mean',
 'B1_Median',
 'B1_Min_Val',
 'B1_Skewnes',
 'B1_Standar',
 'B1_Sum',
 'B1_Var_Coe',
 'B2_Amplitu',
 'B2_Contras',
 'B2_Dissimi',
 'B2_Energy',
 'B2_Entropy',
 'B2_Homogen',
 'B2_Kurtosi',
 'B2_Max_Val',
 'B2_Mean',
 'B2_Median',
 'B2_Min_Val',
 'B2_Skewnes',
 'B2_Standar',
 'B2_Sum',
 'B2_Var_Coe',
 'B3_Amplitu',
 'B3_Contras',
 'B3_Dissimi',
 'B3_Energy',
 'B3_Entropy',
 'B3_Homogen',
 'B3_Kurtosi',
 'B3_Max_Val',
 'B3_Mean',
 'B3_Median',
 'B3_Min_Val',
 'B3_Skewnes',
 'B3_Standar',
 'B3_Sum',
 'B3_Var_Coe',
 'BAINIR_max',
 'BAINIR_mea',
 'BAINIR_min',
 'BAINIR_std',
 'BAINIR_sum',
 'BAI_max',
 'BAI_mean',
 'BAI_min',
 'BAI_stddev',
 'BAI_sum',
 'CONTR_max',
 'CONTR_mean',
 'CONTR_min',
 'CONTR_stdd',
 'CONTR_sum',
 'CORR_max',
 'CORR_mean',
 'CORR_min',
 'CORR_stdde',
 'CORR_sum',
 'ENTR_max',
 'ENTR_mean',
 'ENTR_min',
 'ENTR_stdde',
 'ENTR_sum',
 'MOC1_max',
 'MOC1_mean',
 'MOC1_min',
 'MOC1_stdde',
 'MOC1_sum',
 'NDVI_max',
 'NDVI_mean',
 'NDVI_min',
 'NDVI_stdde',
 'NDVI_sum',
 'PBOX_AREA',
 'PBOX_LEN',
 'PBOX_PERIM',
 'PBOX_WIDTH',
 'PCIRCLE',
 'PDENSITY',
 'PELLIP_FIT',
 'PGYRATIUS',
 'POLRADIUS',
 'POL_ANGLE',
 'PRECTFIT',
 'PSAHPEIDX',
 'P_AREA',
 'P_COMPAC',
 'P_FRACDIM',
 'P_PERARAT',
 'P_PERIM',
 'TARGET',
 'geometry']

# %%
altamira_merge
# Out:
#             DN   ASM_max  ASM_mean   ASM_min  ASM_stddev   ASM_sum  \
# 0            1       NaN       NaN       NaN         NaN       NaN
# 1            2       NaN       NaN       NaN         NaN       NaN
# 2            3       NaN       NaN       NaN         NaN       NaN
# 3            4       NaN       NaN       NaN         NaN       NaN
# 4            6       NaN       NaN       NaN         NaN       NaN
# ...        ...       ...       ...       ...         ...       ...
# 228786  176701  0.004339  0.004001  0.003691    0.000168  0.300074
# 228787  176709  0.006446  0.004522  0.003992    0.000547  0.379877
# 228788  176716  0.004273  0.003844  0.003498    0.000195  0.184513
# 228789  176708  0.004583  0.004184  0.003967    0.000156  0.255227
# 228790  176707  0.004372  0.003805  0.003452    0.000253  0.167413
#
#         B0_Amplitu  B0_Contras  B0_Dissimi  B0_Energy  ...  POL_ANGLE  \
# 0       141.645203   63.750000    6.250000   0.353553  ...   0.043391
# ...

# %%
maraba_target = gpd.read_file("C:\\Users\\brdia\\Downloads\\dados\\maraba_target.shp")

# %%
maraba_target
# Out:
#             DN _class                                           geometry
# 0          853   None  POLYGON ((698230.463 9419361.435, 698227.903 9...
# 1          950   None  POLYGON ((699270.978 9420586.111, 699274.978 9...
# 2          951   None  POLYGON ((699654.966 9420590.650, 699662.966 9...
# 3          953   None  POLYGON ((699246.979 9420585.827, 699256.979 9...
# 4          954   None  POLYGON ((698944.989 9420582.257, 698954.989 9...
# ...        ...    ...                                                ...
# 465540  255235   None  POLYGON ((707752.706 9407089.829, 707754.706 9...
# 465541  255349   None  POLYGON ((707868.702 9407089.829, 707874.702 9...
# 465542  255244   None  POLYGON ((707700.708 9407091.829, 707712.707 9...
# 465543  255233   None  MULTIPOLYGON (((707562.712 9407073.830, 707566...
# 465544  245480   None  MULTIPOLYGON (((706404.749 9407089.829, 706412...
#
# [465545 rows x 3 columns]

# %%
maraba_merge = maraba.merge(maraba_target[['DN','_class']], left_on = 'DN', right_on = 'DN' )

# %%
maraba_merge
# Out:
#             DN   ASM_MIN   ASM_MAX    ASM_SUM  ASM_MEAN  ASM_STDDEV  MOC1_MIN  \
# 0          853  0.016844  0.099509  44.301570  0.039170    0.017333 -0.273886
# 1          950  0.010588  0.010702   0.021290  0.010645    0.000057 -0.322564
# 2          951  0.028526  0.029357   0.201978  0.028854    0.000289 -0.201899
# 3          953       NaN       NaN        NaN       NaN         NaN       NaN
# 4          954  0.016141  0.016381   0.048793  0.016264    0.000098 -0.276726
# ...        ...       ...       ...        ...       ...         ...       ...
# 465540  255235  0.001764  0.002088   0.070765  0.001913    0.000094 -0.350794
# 465541  255349  0.002012  0.002414   0.112950  0.002172    0.000088 -0.330913
# 465542  255244  0.001716  0.002478   0.241096  0.002134    0.000120 -0.346296
# 465543  255233  0.001390  0.003685   0.333867  0.001757    0.000418 -0.523145
# 465544  245480  0.001966  0.003491   0.483117  0.002640    0.000380 -0.360756
#
# ...

# %%
sorted(maraba_merge)
# Out:
# ['ASM_MAX',
#  'ASM_MEAN',
#  'ASM_MIN',
#  'ASM_STDDEV',
#  'ASM_SUM',
#  'B0_Amplitu',
#  'B0_Contras',
#  'B0_Dissimi',
#  'B0_Energy',
#  'B0_Entropy',
#  'B0_Homogen',
#  'B0_Kurtosi',
#  'B0_Max_Val',
#  'B0_Mean',
#  'B0_Median',
#  'B0_Min_Val',
#  'B0_Skewnes',
#  'B0_Standar',
#  'B0_Sum',
#  'B0_Var_Coe',
#  'B1_Amplitu',
#  'B1_Contras',
#  'B1_Dissimi',
#  'B1_Energy',
#  'B1_Entropy',
#  'B1_Homogen',
#  'B1_Kurtosi',
#  'B1_Max_Val',
#  'B1_Mean',
#  'B1_Median',
#  'B1_Min_Val',
#  'B1_Skewnes',
#  'B1_Standar',
#  'B1_Sum',
#  'B1_Var_Coe',
#  'B2_Amplitu',
#  'B2_Contras',
#  'B2_Dissimi',
#  'B2_Energy',
#  'B2_Entropy',
#  'B2_Homogen',
#  'B2_Kurtosi',
#  'B2_Max_Val',
#  'B2_Mean',
#  'B2_Median',
#  'B2_Min_Val',
#  'B2_Skewnes',
#  'B2_Standar',
#  'B2_Sum',
#  'B2_Var_Coe',
#  'B3_Amplitu',
#  'B3_Contras',
#  'B3_Dissimi',
#  'B3_Energy',
#  'B3_Entropy',
#  'B3_Homogen',
#  'B3_Kurtosi',
#  'B3_Max_Val',
#  'B3_Mean',
#  'B3_Median',
#  'B3_Min_Val',
# ...

# %%
maraba_merge = maraba_merge[['DN',
'ASM_MAX',
 'ASM_MEAN',
 'ASM_MIN',
 'ASM_STDDEV',
 'ASM_SUM',
 'B0_Amplitu',
 'B0_Contras',
 'B0_Dissimi',
 'B0_Energy',
 'B0_Entropy',
 'B0_Homogen',
 'B0_Kurtosi',
 'B0_Max_Val',
 'B0_Mean',
 'B0_Median',
 'B0_Min_Val',
 'B0_Skewnes',
 'B0_Standar',
 'B0_Sum',
 'B0_Var_Coe',
 'B1_Amplitu',
 'B1_Contras',
 'B1_Dissimi',
 'B1_Energy',
 'B1_Entropy',
 'B1_Homogen',
 'B1_Kurtosi',
 'B1_Max_Val',
 'B1_Mean',
 'B1_Median',
 'B1_Min_Val',
 'B1_Skewnes',
 'B1_Standar',
 'B1_Sum',
 'B1_Var_Coe',
 'B2_Amplitu',
 'B2_Contras',
 'B2_Dissimi',
 'B2_Energy',
 'B2_Entropy',
 'B2_Homogen',
 'B2_Kurtosi',
 'B2_Max_Val',
 'B2_Mean',
 'B2_Median',
 'B2_Min_Val',
 'B2_Skewnes',
 'B2_Standar',
 'B2_Sum',
 'B2_Var_Coe',
 'B3_Amplitu',
 'B3_Contras',
 'B3_Dissimi',
 'B3_Energy',
 'B3_Entropy',
 'B3_Homogen',
 'B3_Kurtosi',
 'B3_Max_Val',
 'B3_Mean',
 'B3_Median',
 'B3_Min_Val',
 'B3_Skewnes',
 'B3_Standar',
 'B3_Sum',
 'B3_Var_Coe',
 'BAI [MAX]',
 'BAI [MEAN]',
 'BAI [MIN]',
 'BAI [STDDEV',
 'BAI [SUM]',
 'BAINIR [MAX',
 'BAINIR [MEA',
 'BAINIR [MIN',
 'BAINIR [STD',
 'BAINIR [SUM',
 'CONTR_MAX',
 'CONTR_MEAN',
 'CONTR_MIN',
 'CONTR_STDD',
 'CONTR_SUM',
 'Corr_MAX',
 'Corr_MEAN',
 'Corr_MIN',
 'Corr_STDDE',
 'Corr_SUM',
 'ENTR_MAX',
 'ENTR_MEAN',
 'ENTR_MIN',
 'ENTR_STDDE',
 'ENTR_SUM',
 'MOC1_MAX',
 'MOC1_MEAN',
 'MOC1_MIN',
 'MOC1_STDDE',
 'MOC1_SUM',
 'NDVI [MAX]',
 'NDVI [MEAN]',
 'NDVI [MIN]',
 'NDVI [STDDE',
 'NDVI [SUM]',
 'PBOX_AREA',
 'PBOX_LEN',
 'PBOX_PERIM',
 'PBOX_WIDTH',
 'PCIRCLE',
 'PDENSITY',
 'PELLIP_FIT',
 'PGYRATIUS',
 'POLRADIUS',
 'POL_ANGLE',
 'PRECTFIT',
 'PSAHPEIDX',
 'P_AREA',
 'P_COMPAC',
 'P_FRACDIM',
 'P_PERARAT',
 'P_PERIM',
 '_class',
 'geometry']]

# %%
maraba_merge.columns = ['ID',
 'ASM_max',
 'ASM_mean',
 'ASM_min',
 'ASM_stddev',
 'ASM_sum',
 'B0_Amplitu',
 'B0_Contras',
 'B0_Dissimi',
 'B0_Energy',
 'B0_Entropy',
 'B0_Homogen',
 'B0_Kurtosi',
 'B0_Max_Val',
 'B0_Mean',
 'B0_Median',
 'B0_Min_Val',
 'B0_Skewnes',
 'B0_Standar',
 'B0_Sum',
 'B0_Var_Coe',
 'B1_Amplitu',
 'B1_Contras',
 'B1_Dissimi',
 'B1_Energy',
 'B1_Entropy',
 'B1_Homogen',
 'B1_Kurtosi',
 'B1_Max_Val',
 'B1_Mean',
 'B1_Median',
 'B1_Min_Val',
 'B1_Skewnes',
 'B1_Standar',
 'B1_Sum',
 'B1_Var_Coe',
 'B2_Amplitu',
 'B2_Contras',
 'B2_Dissimi',
 'B2_Energy',
 'B2_Entropy',
 'B2_Homogen',
 'B2_Kurtosi',
 'B2_Max_Val',
 'B2_Mean',
 'B2_Median',
 'B2_Min_Val',
 'B2_Skewnes',
 'B2_Standar',
 'B2_Sum',
 'B2_Var_Coe',
 'B3_Amplitu',
 'B3_Contras',
 'B3_Dissimi',
 'B3_Energy',
 'B3_Entropy',
 'B3_Homogen',
 'B3_Kurtosi',
 'B3_Max_Val',
 'B3_Mean',
 'B3_Median',
 'B3_Min_Val',
 'B3_Skewnes',
 'B3_Standar',
 'B3_Sum',
 'B3_Var_Coe',
 'BAINIR_max',
 'BAINIR_mea',
 'BAINIR_min',
 'BAINIR_std',
 'BAINIR_sum',
 'BAI_max',
 'BAI_mean',
 'BAI_min',
 'BAI_stddev',
 'BAI_sum',
 'CONTR_max',
 'CONTR_mean',
 'CONTR_min',
 'CONTR_stdd',
 'CONTR_sum',
 'CORR_max',
 'CORR_mean',
 'CORR_min',
 'CORR_stdde',
 'CORR_sum',
 'ENTR_max',
 'ENTR_mean',
 'ENTR_min',
 'ENTR_stdde',
 'ENTR_sum',
 'MOC1_max',
 'MOC1_mean',
 'MOC1_min',
 'MOC1_stdde',
 'MOC1_sum',
 'NDVI_max',
 'NDVI_mean',
 'NDVI_min',
 'NDVI_stdde',
 'NDVI_sum',
 'PBOX_AREA',
 'PBOX_LEN',
 'PBOX_PERIM',
 'PBOX_WIDTH',
 'PCIRCLE',
 'PDENSITY',
 'PELLIP_FIT',
 'PGYRATIUS',
 'POLRADIUS',
 'POL_ANGLE',
 'PRECTFIT',
 'PSAHPEIDX',
 'P_AREA',
 'P_COMPAC',
 'P_FRACDIM',
 'P_PERARAT',
 'P_PERIM',
 'TARGET',
 'geometry']

# %%
maraba_merge
# Out:
#             DN   ASM_max  ASM_mean   ASM_min  ASM_stddev    ASM_sum  \
# 0          853  0.099509  0.039170  0.016844    0.017333  44.301570
# 1          950  0.010702  0.010645  0.010588    0.000057   0.021290
# 2          951  0.029357  0.028854  0.028526    0.000289   0.201978
# 3          953       NaN       NaN       NaN         NaN        NaN
# 4          954  0.016381  0.016264  0.016141    0.000098   0.048793
# ...        ...       ...       ...       ...         ...        ...
# 465540  255235  0.002088  0.001913  0.001764    0.000094   0.070765
# 465541  255349  0.002414  0.002172  0.002012    0.000088   0.112950
# 465542  255244  0.002478  0.002134  0.001716    0.000120   0.241096
# 465543  255233  0.003685  0.001757  0.001390    0.000418   0.333867
# 465544  245480  0.003491  0.002640  0.001966    0.000380   0.483117
#
#         B0_Amplitu  B0_Contras  B0_Dissimi  B0_Energy  ...  POL_ANGLE  \
# 0       110.903229    2.647619    1.215238   0.167066  ...  -1.569741
# ...

# %%
cameta_merge = cameta 
cameta_merge
# Out:
#           DN   ASM_min   ASM_max   ASM_sum  ASM_mean  ASM_stddev  CONTR_min  \
# 0          1       NaN       NaN       NaN       NaN         NaN        NaN
# 1          2       NaN       NaN       NaN       NaN         NaN        NaN
# 2          3       NaN       NaN       NaN       NaN         NaN        NaN
# 3          4       NaN       NaN       NaN       NaN         NaN        NaN
# 4          5       NaN       NaN       NaN       NaN         NaN        NaN
# ...      ...       ...       ...       ...       ...         ...        ...
# 47829  10550  0.001990  0.003174  0.167017  0.002569    0.000320  44.184086
# 47830  16321  0.001453  0.002375  0.056719  0.001830    0.000298  67.676147
# 47831  11986  0.001636  0.002689  0.181154  0.002059    0.000323  52.784195
# 47832  13568  0.001508  0.002084  0.063731  0.001722    0.000155  55.013206
# 47833   9649  0.002064  0.003465  0.347068  0.002941    0.000395  29.043968
#
# ...

# %%
sorted(cameta_merge)
# Out:
# ['ASM_max',
#  'ASM_mean',
#  'ASM_min',
#  'ASM_stddev',
#  'ASM_sum',
#  'B0_Amplitu',
#  'B0_Contras',
#  'B0_Dissimi',
#  'B0_Energy',
#  'B0_Entropy',
#  'B0_Homogen',
#  'B0_Kurtosi',
#  'B0_Max_Val',
#  'B0_Mean',
#  'B0_Median',
#  'B0_Min_Val',
#  'B0_Skewnes',
#  'B0_Standar',
#  'B0_Sum',
#  'B0_Var_Coe',
#  'B1_Amplitu',
#  'B1_Contras',
#  'B1_Dissimi',
#  'B1_Energy',
#  'B1_Entropy',
#  'B1_Homogen',
#  'B1_Kurtosi',
#  'B1_Max_Val',
#  'B1_Mean',
#  'B1_Median',
#  'B1_Min_Val',
#  'B1_Skewnes',
#  'B1_Standar',
#  'B1_Sum',
#  'B1_Var_Coe',
#  'B2_Amplitu',
#  'B2_Contras',
#  'B2_Dissimi',
#  'B2_Energy',
#  'B2_Entropy',
#  'B2_Homogen',
#  'B2_Kurtosi',
#  'B2_Max_Val',
#  'B2_Mean',
#  'B2_Median',
#  'B2_Min_Val',
#  'B2_Skewnes',
#  'B2_Standar',
#  'B2_Sum',
#  'B2_Var_Coe',
#  'B3_Amplitu',
#  'B3_Contras',
#  'B3_Dissimi',
#  'B3_Energy',
#  'B3_Entropy',
#  'B3_Homogen',
#  'B3_Kurtosi',
#  'B3_Max_Val',
#  'B3_Mean',
#  'B3_Median',
#  'B3_Min_Val',
# ...

# %%
cameta_merge = cameta_merge[[
     'ID',
'ASM_max',
 'ASM_mean',
 'ASM_min',
 'ASM_stddev',
 'ASM_sum',
 'B0_Amplitu',
 'B0_Contras',
 'B0_Dissimi',
 'B0_Energy',
 'B0_Entropy',
 'B0_Homogen',
 'B0_Kurtosi',
 'B0_Max_Val',
 'B0_Mean',
 'B0_Median',
 'B0_Min_Val',
 'B0_Skewnes',
 'B0_Standar',
 'B0_Sum',
 'B0_Var_Coe',
 'B1_Amplitu',
 'B1_Contras',
 'B1_Dissimi',
 'B1_Energy',
 'B1_Entropy',
 'B1_Homogen',
 'B1_Kurtosi',
 'B1_Max_Val',
 'B1_Mean',
 'B1_Median',
 'B1_Min_Val',
 'B1_Skewnes',
 'B1_Standar',
 'B1_Sum',
 'B1_Var_Coe',
 'B2_Amplitu',
 'B2_Contras',
 'B2_Dissimi',
 'B2_Energy',
 'B2_Entropy',
 'B2_Homogen',
 'B2_Kurtosi',
 'B2_Max_Val',
 'B2_Mean',
 'B2_Median',
 'B2_Min_Val',
 'B2_Skewnes',
 'B2_Standar',
 'B2_Sum',
 'B2_Var_Coe',
 'B3_Amplitu',
 'B3_Contras',
 'B3_Dissimi',
 'B3_Energy',
 'B3_Entropy',
 'B3_Homogen',
 'B3_Kurtosi',
 'B3_Max_Val',
 'B3_Mean',
 'B3_Median',
 'B3_Min_Val',
 'B3_Skewnes',
 'B3_Standar',
 'B3_Sum',
 'B3_Var_Coe',
 'BAINIR_max',
 'BAINIR_mea',
 'BAINIR_min',
 'BAINIR_std',
 'BAINIR_sum',
 'BAI_max',
 'BAI_mean',
 'BAI_min',
 'BAI_stddev',
 'BAI_sum',
 'CONTR_max',
 'CONTR_mean',
 'CONTR_min',
 'CONTR_stdd',
 'CONTR_sum',
 'CORR_max',
 'CORR_mean',
 'CORR_min',
 'CORR_stdde',
 'CORR_sum',
 'ENTR_max',
 'ENTR_mean',
 'ENTR_min',
 'ENTR_stdde',
 'ENTR_sum',
 'MOC1_max',
 'MOC1_mean',
 'MOC1_min',
 'MOC1_stdde',
 'MOC1_sum',
 'NDVI_max',
 'NDVI_mean',
 'NDVI_min',
 'NDVI_stdde',
 'NDVI_sum',
 'PBOX_AREA',
 'PBOX_LEN',
 'PBOX_PERIM',
 'PBOX_WIDTH',
 'PCIRCLE',
 'PDENSITY',
 'PELLIP_FIT',
 'PGYRATIUS',
 'POLRADIUS',
 'POL_ANGLE',
 'PRECTFIT',
 'PSAHPEIDX',
 'P_AREA',
 'P_COMPAC',
 'P_FRACDIM',
 'P_PERARAT',
 'P_PERIM',
 'TARGET',
 'geometry']]

# %%
maraba_merge
# Out:
#             ID   ASM_max  ASM_mean   ASM_min  ASM_stddev    ASM_sum  \
# 0          853  0.099509  0.039170  0.016844    0.017333  44.301570
# 1          950  0.010702  0.010645  0.010588    0.000057   0.021290
# 2          951  0.029357  0.028854  0.028526    0.000289   0.201978
# 3          953       NaN       NaN       NaN         NaN        NaN
# 4          954  0.016381  0.016264  0.016141    0.000098   0.048793
# ...        ...       ...       ...       ...         ...        ...
# 465540  255235  0.002088  0.001913  0.001764    0.000094   0.070765
# 465541  255349  0.002414  0.002172  0.002012    0.000088   0.112950
# 465542  255244  0.002478  0.002134  0.001716    0.000120   0.241096
# 465543  255233  0.003685  0.001757  0.001390    0.000418   0.333867
# 465544  245480  0.003491  0.002640  0.001966    0.000380   0.483117
#
#         B0_Amplitu  B0_Contras  B0_Dissimi  B0_Energy  ...  POL_ANGLE  \
# 0       110.903229    2.647619    1.215238   0.167066  ...  -1.569741
# ...

# %%
cameta_merge.to_file("C:\\Bruno\\packages\\amazonULC\\data-raw\\raw-images\\nivel1_cameta_v2.shp")

# %%
altamira_merge.to_file("C:\\Bruno\\packages\\amazonULC\\data-raw\\raw-images\\nivel1_altamira.shp")

# %%
maraba_merge.to_file("C:\\Bruno\\packages\\amazonULC\\data-raw\\raw-images\\nivel1_maraba.shp")

# %%
santarem = gpd.read_file("C:\\Bruno\\packages\\amazonULC\\data-raw\\raw-images\\WGS-84\\nivel1_santarem.shp")

# %%
santarem
# Out:
#           ID   ASM_min   ASM_max  ASM_range    ASM_sum  ASM_mean   ASM_var  \
# 0          1  0.104167  0.162326   0.058160  12.282986  0.115877  0.000149
# 1          2  0.104167  0.177083   0.072917  33.243056  0.118303  0.000218
# 2          3  0.104167  0.161458   0.057292  15.741320  0.115745  0.000241
# 3          4  0.104167  0.223958   0.119792  19.033855  0.118962  0.000376
# 4          5  0.104167  0.154514   0.050347  14.699653  0.111361  0.000106
# ...      ...       ...       ...        ...        ...       ...       ...
# 65817  64072  0.104167  0.223090   0.118924  36.619793  0.117749  0.000239
# 65818  64056  0.104167  0.180556   0.076389  63.664065  0.112085  0.000133
# 65819  64057  0.104167  0.223090   0.118924  32.250001  0.117273  0.000322
# 65820  64063  0.104167  0.398438   0.294271  85.526912  0.123060  0.000713
# 65821  64066  0.104167  0.245660   0.141493  48.740453  0.113880  0.000198
#
# ...

# %%
sorted(santarem)
# Out:
# ['ASM_max',
#  'ASM_mean',
#  'ASM_min',
#  'ASM_range',
#  'ASM_sum',
#  'ASM_var',
#  'B0_Amplitu',
#  'B0_Contras',
#  'B0_Dissimi',
#  'B0_Energy',
#  'B0_Entropy',
#  'B0_Homogen',
#  'B0_Kurtosi',
#  'B0_Max_Val',
#  'B0_Mean',
#  'B0_Median',
#  'B0_Min_Val',
#  'B0_Skewnes',
#  'B0_Sum',
#  'B0_Varianc',
#  'B1_Amplitu',
#  'B1_Contras',
#  'B1_Dissimi',
#  'B1_Energy',
#  'B1_Entropy',
#  'B1_Homogen',
#  'B1_Kurtosi',
#  'B1_Max_Val',
#  'B1_Mean',
#  'B1_Median',
#  'B1_Min_Val',
#  'B1_Skewnes',
#  'B1_Sum',
#  'B1_Varianc',
#  'B2_Amplitu',
#  'B2_Contras',
#  'B2_Dissimi',
#  'B2_Energy',
#  'B2_Entropy',
#  'B2_Homogen',
#  'B2_Kurtosi',
#  'B2_Max_Val',
#  'B2_Mean',
#  'B2_Median',
#  'B2_Min_Val',
#  'B2_Skewnes',
#  'B2_Sum',
#  'B2_Varianc',
#  'B3_Amplitu',
#  'B3_Contras',
#  'B3_Dissimi',
#  'B3_Energy',
#  'B3_Entropy',
#  'B3_Homogen',
#  'B3_Kurtosi',
#  'B3_Max_Val',
#  'B3_Mean',
#  'B3_Median',
#  'B3_Min_Val',
#  'B3_Skewnes',
#  'B3_Sum',
# ...

# %%
santarem = santarem[[ 'ID',
 'ASM_max',
 'ASM_mean',
 'ASM_min',
 'ASM_range',
 'ASM_sum',
 'ASM_var',
 'B0_Amplitu',
 'B0_Contras',
 'B0_Dissimi',
 'B0_Energy',
 'B0_Entropy',
 'B0_Homogen',
 'B0_Kurtosi',
 'B0_Max_Val',
 'B0_Mean',
 'B0_Median',
 'B0_Min_Val',
 'B0_Skewnes',
 'B0_Sum',
 'B0_Varianc',
 'B1_Amplitu',
 'B1_Contras',
 'B1_Dissimi',
 'B1_Energy',
 'B1_Entropy',
 'B1_Homogen',
 'B1_Kurtosi',
 'B1_Max_Val',
 'B1_Mean',
 'B1_Median',
 'B1_Min_Val',
 'B1_Skewnes',
 'B1_Sum',
 'B1_Varianc',
 'B2_Amplitu',
 'B2_Contras',
 'B2_Dissimi',
 'B2_Energy',
 'B2_Entropy',
 'B2_Homogen',
 'B2_Kurtosi',
 'B2_Max_Val',
 'B2_Mean',
 'B2_Median',
 'B2_Min_Val',
 'B2_Skewnes',
 'B2_Sum',
 'B2_Varianc',
 'B3_Amplitu',
 'B3_Contras',
 'B3_Dissimi',
 'B3_Energy',
 'B3_Entropy',
 'B3_Homogen',
 'B3_Kurtosi',
 'B3_Max_Val',
 'B3_Mean',
 'B3_Median',
 'B3_Min_Val',
 'B3_Skewnes',
 'B3_Sum',
 'B3_Varianc',
 'BAI_max',
 'BAI_mean',
 'BAI_min',
 'BAI_range',
 'BAI_sum',
 'BAI_var',
 'COR_max',
 'COR_mean',
 'COR_min',
 'COR_range',
 'COR_sum',
 'COR_var',
 'COT_max',
 'COT_mean',
 'COT_min',
 'COT_range',
 'COT_sum',
 'COT_var',
 'DE_max',
 'DE_mean',
 'DE_min',
 'DE_range',
 'DE_sum',
 'DE_var',
 'DV_max',
 'DV_mean',
 'DV_min',
 'DV_range',
 'DV_sum',
 'DV_var',
 'ENT_max',
 'ENT_mean',
 'ENT_min',
 'ENT_range',
 'ENT_sum',
 'ENT_var',
 'IDM_max',
 'IDM_mean',
 'IDM_min',
 'IDM_range',
 'IDM_sum',
 'IDM_var',
 'IFAG_max',
 'IFAG_mean',
 'IFAG_min',
 'IFAG_range',
 'IFAG_sum',
 'IFAG_var',
 'IFSE_max',
 'IFSE_mean',
 'IFSE_min',
 'IFSE_range',
 'IFSE_sum',
 'IFSE_var',
 'IFVE_max',
 'IFVE_mean',
 'IFVE_min',
 'IFVE_range',
 'IFVE_sum',
 'IFVE_var',
 'MC1_max',
 'MC1_mean',
 'MC1_min',
 'MC1_range',
 'MC1_sum',
 'MC1_var',
 'MC2_max',
 'MC2_mean',
 'MC2_min',
 'MC2_range',
 'MC2_sum',
 'MC2_var',
 'NDRI_max',
 'NDRI_mean',
 'NDRI_min',
 'NDRI_range',
 'NDRI_sum',
 'NDRI_var',
 'NDVI_max',
 'NDVI_mean',
 'NDVI_min',
 'NDVI_range',
 'NDVI_sum',
 'NDVI_var',
 'NDWI_max',
 'NDWI_mean',
 'NDWI_min',
 'NDWI_range',
 'NDWI_sum',
 'NDWI_var',
 'PBOX_AREA',
 'PBOX_LEN',
 'PBOX_PERIM',
 'PBOX_WIDTH',
 'PCIRCLE',
 'PDENSITY',
 'PELLIP_FIT',
 'PGYRATIUS',
 'POLRADIUS',
 'POL_ANGLE',
 'PRECTFIT',
 'PSAHPEIDX',
 'P_AREA',
 'P_COMPAC',
 'P_FRACDIM',
 'P_PERARAT',
 'P_PERIM',
 'Road_perc',
 'Road_pres',
 'SA_max',
 'SA_mean',
 'SA_min',
 'SA_range',
 'SA_sum',
 'SA_var',
 'SE_max',
 'SE_mean',
 'SE_min',
 'SE_range',
 'SE_sum',
 'SE_var',
 'SV_max',
 'SV_mean',
 'SV_min',
 'SV_range',
 'SV_sum',
 'SV_var',
 'VAR_max',
 'VAR_mean',
 'VAR_min',
 'VAR_range',
 'VAR_sum',
 'VAR_var',
 'TARGET',
 'geometry']]

# %%
santarem.to_file("C:\\Bruno\\packages\\amazonULC\\data-raw\\raw-images\\nivel1_santarem.shp")
