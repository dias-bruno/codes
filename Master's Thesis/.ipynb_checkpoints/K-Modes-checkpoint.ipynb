# %% [markdown]
# # <center> Preparação e Classificação não supervisionada da grade celular </center>
#
# <br/>
#
# <div style="text-align: center;font-size: 90%;">
#     Bruno Dias dos Santos<sup><a href="https://orcid.org/0000-0001-6181-2158"><i class="fab fa-lg fa-orcid" style="color: #a6ce39"></i></a></sup><sup><a href="https://orcid.org/0000-0002-0082-9498"><i class="fab fa-lg fa-orcid" style="color: #a6ce39"></i></a></sup><i class="fab fa-lg fa-orcid" style="color: #a6ce39"></i></a></sup>
#     <br/><br/>
#     Programa de Pós-Graduação em Computação Aplicada, Instituto Nacional de Pesquisas Espaciais (INPE)
#     <br/>
#     Avenida dos Astronautas, 1758, Jardim da Granja, São José dos Campos, SP 12227-010, Brasil
#     <br/><br/>
#     Contato: <div><a href="mailto:bruno.santos@inpe.br">bruno.santos@inpe.br</a></div>
#     <br/><br/>
#     Última atualização: 18 de Abril de 2022
# </div>
# <br/>
#
# <div style="text-align: justify;  margin-left: 25%; margin-right: 25%;">
# <b>Resumo.</b>  Este Notebook apresenta uma metodologia para tratar variáveis e posterior classificação não supervisionada  algoritmo <i> Agglomerative Clustering </i>. Dado uma tabela de arquivo shapefile (.shp) os atributos serão tratados a partir do preenchimento de valores faltantes e normalizados. Posteriormente, serão construidos modelos com o algoritmo não supervisionado.
# </div>
#
# <br/>

# %% [markdown]
# ### 1º Etapa: Tratamento e seleção de variáveis

# %% [markdown]
# Importação das bibliotecas:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import shapely
import folium
import mapclassify
import plotly.express as px
import plotly.graph_objects as go
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.cluster import KMeans, SpectralClustering, AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn_som.som import SOM
from kmodes.kmodes import KModes

# %% [markdown]
# Leitura do shapefile e criação de um GeoDataFrame:

# %%
amb = gpd.read_file("D:\\00_INPE\\0_DISSERTACAO\\VALIDACAO\\1_DIM_AMB\\clusters_ambiental_cameta_v6.shp")

# %%
amb
# Out:
#         ID      AGUA     CA_VA     CA_VH     PD_VH     PD_VA  HC_6  HC_5  \
# 0      145 -0.500827 -0.065312 -0.295410  0.248824 -0.508848     2     2
# 1      146 -0.500827 -0.087252 -0.124302  0.943893 -0.654391     2     2
# 2      147 -0.500827  0.027637 -0.360081 -0.446245 -0.217763     2     2
# 3      148 -0.500827  0.044185 -0.303392  0.248823 -0.363306     2     2
# 4      149 -0.500827  0.098865 -0.360081 -0.446245 -0.799934     2     2
# ...    ...       ...       ...       ...       ...       ...   ...   ...
# 4149  4538 -0.500827  0.853997 -0.360081 -0.446245  0.946487     2     2
# 4150  4539 -0.500827  0.853999 -0.360081 -0.446245 -0.217799     2     2
# 4151  4540 -0.500827  0.854001 -0.360081 -0.446245 -0.072264     2     2
# 4152  4541 -0.500827  0.849220 -0.360081 -0.446245 -0.363335     2     2
# 4153  4542 -0.500827  0.829083 -0.360081 -0.446245 -0.363336     2     2
#
#       HC_4                                           geometry
# 0        2  POLYGON ((662262.846 9749158.881, 662261.352 9...
# 1        2  POLYGON ((662362.906 9749160.373, 662361.411 9...
# 2        2  POLYGON ((662462.965 9749161.865, 662461.471 9...
# 3        2  POLYGON ((662563.025 9749163.357, 662561.530 9...
# 4        2  POLYGON ((662663.085 9749164.849, 662661.590 9...
# ...    ...                                                ...
# 4149     2  POLYGON ((668374.408 9755346.601, 668372.896 9...
# 4150     2  POLYGON ((668474.454 9755348.111, 668472.941 9...
# 4151     2  POLYGON ((668574.500 9755349.622, 668572.987 9...
# 4152     2  POLYGON ((668674.545 9755351.133, 668673.032 9...
# 4153     2  POLYGON ((668774.591 9755352.644, 668773.078 9...
#
# [4154 rows x 10 columns]

# %%
urb = gpd.read_file("D:\\00_INPE\\0_DISSERTACAO\\VALIDACAO\\2_DIM_MORF\\cluster_morfo_cameta.shp")

# %%
urb
# Out:
#         id     CA_AS     CA_BR     CA_ES     CA_TC     CA_TF  angular_co  \
# 0      162 -0.434777 -0.371148 -0.833154 -0.681049 -0.514243   -0.994330
# 1      165 -0.434777 -0.371148  1.035589 -0.461514 -0.637723   -0.951615
# 2      166 -0.434777 -0.371148  0.125210 -0.586351 -0.637723   -0.908564
# 3      177 -0.434777 -0.371148 -0.833154 -0.648994 -0.637723   -0.994330
# 4      205 -0.434777 -0.371148 -0.833154 -0.608594 -0.637723    1.036524
# ...    ...       ...       ...       ...       ...       ...         ...
# 1369  4519 -0.434777 -0.371148 -0.419884 -0.634006 -0.637723   -0.994330
# 1370  4535 -0.434777 -0.371148  0.257499 -0.511792 -0.572017   -0.695390
# 1371  4536 -0.434777 -0.371148  1.078666 -0.469354 -0.488093    0.826830
# 1372  4537 -0.434777 -0.371148 -0.600689 -0.681049 -0.637723    2.077054
# 1373  4542 -0.434777 -0.371148 -0.747055 -0.656148 -0.637723    0.528810
#
#       t16_choi_1  t16_choic1  area_per_w  ...  75 [MEAN]  20_00 [MEA  \
# 0      -0.539733   -0.360031    0.557181  ...  -0.485860   -0.511303
# 1       0.286232    0.122314    0.460824  ...  -0.364182   -0.472329
# 2       0.325340    0.124452   -0.092021  ...  -0.412689   -0.468623
# 3      -0.539733   -0.360031   -0.131448  ...  -0.485860   -0.511303
# 4      -0.445999   -0.354076   -0.816664  ...  -0.485860   -0.511085
# ...          ...         ...         ...  ...        ...         ...
# 1369   -0.539733   -0.360031    0.692644  ...  -0.485860   -0.511303
# 1370    0.379911    3.464685    0.649295  ...  -0.485860   -0.482086
# 1371   -0.021183    1.555599    0.083859  ...  -0.485860   -0.283731
# 1372   -0.416479   -0.353432   -0.378613  ...  -0.485860   -0.039263
# 1373   -0.483351   -0.356436   -0.604485  ...  -0.479283   -0.359443
#
#       VAR [MAX]  HC_4  HC_5  HC_6  HC_7  HC_8  HC_9  \
# 0     -0.638362     1     1     1     0     2     2
# 1     -0.017395     1     1     1     0     2     2
# 2     -0.943458     1     1     1     0     2     2
# 3     -0.677595     1     1     1     0     2     2
# 4     -0.966938     1     1     1     0     2     2
# ...         ...   ...   ...   ...   ...   ...   ...
# 1369  -0.742717     1     1     1     0     2     2
# 1370  -0.055167     3     3     3     3     3     3
# 1371  -0.119496     3     3     3     3     3     3
# 1372  -0.234670     1     1     1     0     2     2
# 1373  -0.809907     1     1     1     0     2     2
#
#                                                geometry
# 0     POLYGON ((663963.865 9749184.276, 663962.366 9...
# 1     POLYGON ((664264.045 9749188.765, 664262.546 9...
# 2     POLYGON ((664364.106 9749190.262, 664362.606 9...
# 3     POLYGON ((665464.771 9749206.746, 665463.269 9...
# 4     POLYGON ((668266.483 9749248.847, 668264.973 9...
# ...                                                 ...
# 1369  POLYGON ((666473.545 9755317.952, 666472.038 9...
# 1370  POLYGON ((668074.271 9755342.071, 668072.759 9...
# 1371  POLYGON ((668174.317 9755343.581, 668172.805 9...
# 1372  POLYGON ((668274.362 9755345.091, 668272.850 9...
# 1373  POLYGON ((668774.591 9755352.644, 668773.078 9...
#
# [1374 rows x 22 columns]

# %%
amb = amb[['ID','HC_4']]

# %%
urb = urb[['id', 'HC_9','geometry']]

# %% [markdown]
# Definicação da variável identificadora de cada feição:

# %%
indice = 'id'

# %% [markdown]
# Criando uma base de dados que será utilizada na saída, copiando as informações do 'indice' e o 'TARGET' da base original:

# %%
geom = urb.merge(amb, left_on=indice, right_on='ID', how='left')

# %%
geom
# Out:
#         id  HC_9                                           geometry    ID  \
# 0      162     2  POLYGON ((663963.865 9749184.276, 663962.366 9...   162
# 1      165     2  POLYGON ((664264.045 9749188.765, 664262.546 9...   165
# 2      166     2  POLYGON ((664364.106 9749190.262, 664362.606 9...   166
# 3      177     2  POLYGON ((665464.771 9749206.746, 665463.269 9...   177
# 4      205     2  POLYGON ((668266.483 9749248.847, 668264.973 9...   205
# ...    ...   ...                                                ...   ...
# 1369  4519     2  POLYGON ((666473.545 9755317.952, 666472.038 9...  4519
# 1370  4535     3  POLYGON ((668074.271 9755342.071, 668072.759 9...  4535
# 1371  4536     3  POLYGON ((668174.317 9755343.581, 668172.805 9...  4536
# 1372  4537     2  POLYGON ((668274.362 9755345.091, 668272.850 9...  4537
# 1373  4542     2  POLYGON ((668774.591 9755352.644, 668773.078 9...  4542
#
#       HC_4
# 0        2
# 1        0
# 2        2
# 3        3
# 4        3
# ...    ...
# 1369     2
# 1370     2
# 1371     2
# 1372     0
# 1373     2
#
# [1374 rows x 5 columns]

# %%
geom.plot(column= geom['HC_9'], cmap='tab10',legend=True, categorical=True)
# Out:
# <AxesSubplot:>

# %%
geom['HC_9'].replace(6, 
           2, 
           inplace=True)

geom['HC_9'].replace(7, 
           2, 
           inplace=True)

geom['HC_9'].replace(8, 
           1, 
           inplace=True)

# %%
geom.plot(column= geom['HC_9'], cmap='tab10',legend=True, categorical=True)
# Out:
# <AxesSubplot:>

# %%
geom.explore(column="HC_9", tooltip="HC_9",tiles='cartodbpositron',
             categorical = True, style_kwds=dict(color="grey", weight=0.01, fillOpacity = 0.7))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0107ab6c8105c04a22f5ea66c7e16ac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div id=&#x27;maplegend HC_9&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;HC_9&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;0&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#2ca02c&#x27;&gt;&lt;/span&gt;1&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9467bd&#x27;&gt;&lt;/span&gt;2&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e377c2&#x27;&gt;&lt;/span&gt;3&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#bcbd22&#x27;&gt;&lt;/span&gt;4&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9edae5&#x27;&gt;&lt;/span&gt;5&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0107ab6c8105c04a22f5ea66c7e16ac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0107ab6c8105c04a22f5ea66c7e16ac4 = L.map(
#                 &quot;map_0107ab6c8105c04a22f5ea66c7e16ac4&quot;,
#                 {
#                     center: [-2.2400660617694284, -49.510835147524524],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0107ab6c8105c04a22f5ea66c7e16ac4);
#
#
#
#
#
#             var tile_layer_3c43c561a37178a364ac788e968d4819 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0107ab6c8105c04a22f5ea66c7e16ac4);
#
#
#             map_0107ab6c8105c04a22f5ea66c7e16ac4.fitBounds(
#                 [[-2.2684409869056226, -49.541136684022455], [-2.211691136633234, -49.480533611026594]],
#                 {}
#             );
#
#
#         function geo_json_14e8c0bfd34b3aae201e8d87e7339fe5_styler(feature) {
#             switch(feature.id) {
#                 case &quot;76&quot;: case &quot;112&quot;: case &quot;138&quot;: case &quot;140&quot;: case &quot;141&quot;: case &quot;143&quot;: case &quot;145&quot;: case &quot;146&quot;: case &quot;157&quot;: case &quot;178&quot;: case &quot;179&quot;: case &quot;180&quot;: case &quot;181&quot;: case &quot;182&quot;: case &quot;185&quot;: case &quot;196&quot;: case &quot;197&quot;: case &quot;198&quot;: case &quot;199&quot;: case &quot;200&quot;: case &quot;201&quot;: case &quot;225&quot;: case &quot;226&quot;: case &quot;227&q

# %%
geom.columns
# Out:
# Index(['id', 'HC_9', 'geometry', 'ID', 'HC_4'], dtype='object')

# %%
geom = geom[['id','HC_4', 'HC_9','geometry']]

# %%
geom.isna().any()
# Out:
# id          False
# HC_4        False
# HC_9        False
# geometry    False
# dtype: bool

# %%
geom.iloc[:,1:-1]
# Out:
#       HC_4  HC_9
# 0        2     2
# 1        0     2
# 2        2     2
# 3        3     2
# 4        3     2
# ...    ...   ...
# 1369     2     2
# 1370     2     3
# 1371     2     3
# 1372     0     2
# 1373     2     2
#
# [1374 rows x 2 columns]

# %% [markdown]
# ### 2º Etapa: Classificação Não Supervisionada da Grade Celular

# %% [markdown]
# Criando uma base de dados com as variáveis para o processo de classificação não supervisionada:

# %%
dados = geom.iloc[:,1:-1].to_numpy()
dados
# Out:
# array([[2, 2],
#        [0, 2],
#        [2, 2],
#        ...,
#        [2, 3],
#        [0, 2],
#        [2, 2]], dtype=int64)

# %% [markdown]
# Gerando um gráfico de <i>dendrograma</i> para identificar um bom número de cluster no modelo <b>AC</b>:

# %%
km = KModes(n_clusters=12, init='Huang', n_init=300, verbose=1)
km.fit_predict(dados)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 135, cost: 217.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 6, cost: 286.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 23, cost: 208.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 14, cost: 204.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 46, cost: 140.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 1, cost: 167.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 31, cost: 147.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 8, iteration: 1/100, moves: 0, cost: 440.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 9, iteration: 1/100, moves: 0, cost: 247.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 10, iteration: 1/100, moves: 168, cost: 136.0
# Run 10, iteration: 2/100, moves: 0, cost: 136.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 11, iteration: 1/100, moves: 47, cost: 178.0
# Run 11, iteration: 2/100, moves: 7, cost: 178.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 12, iteration: 1/100, moves: 7, cost: 146.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 13, iteration: 1/100, moves: 245, cost: 332.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 14, iteration: 1/100, moves: 0, cost: 320.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 15, iteration: 1/100, moves: 1, cost: 160.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 16, iteration: 1/100, moves: 46, cost: 131.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 17, iteration: 1/100, moves: 111, cost: 109.0
# Run 17, iteration: 2/100, moves: 11, cost: 109.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run
0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 268, iteration: 1/100, moves: 0, cost: 171.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 269, iteration: 1/100, moves: 110, cost: 131.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 270, iteration: 1/100, moves: 55, cost: 69.0
# Run 270, iteration: 2/100, moves: 10, cost: 69.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 271, iteration: 1/100, moves: 6, cost: 184.0
# Run 271, iteration: 2/100, moves: 0, cost: 184.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 272, iteration: 1/100, moves: 56, cost: 133.0
# Run 272, iteration: 2/100, moves: 11, cost: 133.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 273, iteration: 1/100, moves: 100, cost: 219.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 274, iteration: 1/100, moves: 42, cost: 176.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 275, iteration: 1/100, moves: 0, cost: 338.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 276, iteration: 1/100, moves: 53, cost: 100.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 277, iteration: 1/100, moves: 1, cost: 331.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 278, iteration: 1/100, moves: 224, cost: 253.0
# Run 278, iteration: 2/100, moves: 0, cost: 253.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 279, iteration: 1/100, moves: 230, cost: 344.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 280, iteration: 1/100, moves: 15, cost: 173.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 281, iteration: 1/100, moves: 49, cost: 168.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 282, iteration: 1/100, moves: 50, cost: 166.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 283, iteration: 1/100, moves: 8, cost: 100.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 284, iteration: 1/100, moves: 16, cost: 109.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 285, iteration: 1/100, moves: 43, cost: 209.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 286, iteration: 1/100, moves: 0, cost: 251.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 287, iteration: 1/100, moves: 0, cost: 531.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 288, iteration: 1/100, moves: 196, cost: 120.0
# Run 288, iteration: 2/100, moves: 9, cost: 120.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 289, iteration: 1/100, moves: 111, cost: 115.0
# Run 289, iteration: 2/100, moves: 0, cost: 115.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 290, iteration: 1/100, moves: 0, cost: 316.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 291, iteration: 1/100, moves: 24, cost: 229.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 292, iteration: 1/100, moves: 21, cost: 391.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 293, iteration: 1/100, moves: 13, cost: 306.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 294, iteration: 1/100, moves: 17, cost: 486.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 295, iteration: 1/100, moves: 42, cost: 142.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 296, iteration: 1/100, moves: 13, cost: 137.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 297, iteration: 1/100, moves: 0, cost: 253.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 298, iteration: 1/100, moves: 7, cost: 149.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 299, iteration: 1/100, moves: 0, cost: 133.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 300, iteration: 1/100, moves: 248, cost: 111.0
# Run 300, iteration: 2/100, moves: 13, cost: 111.0
# Best run was number 240
# array([ 5, 11,  5, ...,  7, 11,  5], dtype=uint16)

# %% [markdown]
# Visualizando a quantidade de feições em cada cluster:

# %%
unique, counts = np.unique(km.labels_, return_counts=True)

result = np.column_stack((unique, counts)) 
print (result)
# Out:
# [[  0  77]
#  [  1 111]
#  [  2 106]
#  [  3  60]
#  [  4 234]
#  [  5 262]
#  [  6 168]
#  [  7  35]
#  [  8  28]
#  [  9  43]
#  [ 10  33]
#  [ 11 217]]

# %% [markdown]
# Incluindo o resultado do modelo <b>AC</b> na base de dados:

# %%
geom['umars_12'] = km.labels_

# %% [markdown]
# Visualizando um mapa simples com os clusters do modelo <b>AC</b>:

# %%
geom.plot(column= geom['umars_12'], legend=True, categorical=True)
# Out:
# <AxesSubplot:>

# %%
geom.columns = ['id', 'HC_6', 'HC_4', 'geometry', 'umars_10']

# %% [markdown]
# Visualizando a base de dados e exportando uma chamada shapefile com as informações:

# %%
geom
# Out:
#         id  HC_4  HC_9                                           geometry  \
# 0      162     2     2  POLYGON ((663963.865 9749184.276, 663962.366 9...
# 1      165     0     2  POLYGON ((664264.045 9749188.765, 664262.546 9...
# 2      166     2     2  POLYGON ((664364.106 9749190.262, 664362.606 9...
# 3      177     3     2  POLYGON ((665464.771 9749206.746, 665463.269 9...
# 4      205     3     2  POLYGON ((668266.483 9749248.847, 668264.973 9...
# ...    ...   ...   ...                                                ...
# 1369  4519     2     2  POLYGON ((666473.545 9755317.952, 666472.038 9...
# 1370  4535     2     3  POLYGON ((668074.271 9755342.071, 668072.759 9...
# 1371  4536     2     3  POLYGON ((668174.317 9755343.581, 668172.805 9...
# 1372  4537     0     2  POLYGON ((668274.362 9755345.091, 668272.850 9...
# 1373  4542     2     2  POLYGON ((668774.591 9755352.644, 668773.078 9...
#
#       umars_8  umars_9  umars_10  umars_12
# 0           0        3         5         5
# 1           1        4         6        11
# 2           0        3         5         5
# 3           5        2         9         1
# 4           5        2         9         1
# ...       ...      ...       ...       ...
# 1369        0        3         5         5
# 1370        0        3         8         7
# 1371        0        3         8         7
# 1372        1        4         6        11
# 1373        0        3         5         5
#
# [1374 rows x 8 columns]

# %%
geom.explore(column="umars_7", tooltip="umars_7",tiles='cartodbpositron',
             categorical = True, style_kwds=dict(color="grey", weight=0.01, fillOpacity = 0.7))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5cf0907400925a88c4198cbd422edc3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div id=&#x27;maplegend umars_7&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;umars_7&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;0&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ffbb78&#x27;&gt;&lt;/span&gt;1&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d62728&#x27;&gt;&lt;/span&gt;2&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8c564b&#x27;&gt;&lt;/span&gt;3&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#f7b6d2&#x27;&gt;&lt;/span&gt;4&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#bcbd22&#x27;&gt;&lt;/span&gt;5&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9edae5&#x27;&gt;&lt;/span&gt;6&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5cf0907400925a88c4198cbd422edc3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5cf0907400925a88c4198cbd422edc3e = L.map(
#                 &quot;map_5cf0907400925a88c4198cbd422edc3e&quot;,
#                 {
#                     center: [-2.2400660617694284, -49.510835147524524],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5cf0907400925a88c4198cbd422edc3e);
#
#
#
#
#
#             var tile_layer_ef60bc741ccd08c67bc8209c7240a1c7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5cf0907400925a88c4198cbd422edc3e);
#
#
#             map_5cf0907400925a88c4198cbd422edc3e.fitBounds(
#                 [[-2.2684409869056226, -49.541136684022455], [-2.211691136633234, -49.480533611026594]],
#                 {}
#             );
#
#
#         function geo_json_d7696b547941ef28bf5fde19ae852deb_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;: case &quot;9&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;22&quot;: case &quot;26&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;50&quot;: case &quot;51&quot;: case &quot;60&quot;: case &quot;62&quot;: case &quot;66&quot;: case &quot;72&quot;: case &quot;73&quot;: case &quot;75&quo

# %%
unique, counts = np.unique(geom['umars_10'], return_counts=True)

result = np.column_stack((unique, counts)) 
print (result)
# Out:
# [[  0  89]
#  [  1  77]
#  [  2 291]
#  [  3 174]
#  [  4 106]
#  [  5 262]
#  [  6 217]
#  [  7  37]
#  [  8  35]
#  [  9  86]]

# %%
geom['umars_12'].replace(3, 
           2, 
           inplace=True)

geom['umars_12'].replace(6, 
           5, 
           inplace=True)

geom['umars_12'].replace(11, 
           5, 
           inplace=True)

geom['umars_12'].replace(9, 
           7, 
           inplace=True)

geom['umars_12'].replace(10, 
           4, 
           inplace=True)

# %%
geom.to_file("D:\\00_inpe\\0_dissertacao\\validacao\\3_umars\\clusters_umars_cameta.shp")
